# %% [markdown]
# # Model selection, training data and test data
#
# Given data $(x_1, y_1), \ldots, (x_n,y_n)$, we have seen that linear regression can be used to fit a model of the form
#
# \begin{equation}
# f(x) = \beta_0 + \beta_1 g_1(x) + \ldots + \beta_k g_k(x)
# \end{equation}
#
# for any functions $g_1, \ldots, g_k$. Increasing $k$ increases the complexity of the model and improves the fit (decreases the SSE). For example, the SSE for the quadratic model can be no larger than that of a linear model, and is generally strictly smaller (as we saw in the first notebook). Should we keep increasing $k$ as long as the SSE keeps decreasing?  In fact, with $n$ data points, we can get _exactly_ zero SSE with an $(n-1)$th order polynomial fit!
#
# Is it a good idea to do this? Generally not. The reason is the point of a model is to make good predictions on _new_ data, not just on the already avaialable data $(x_1, y_1), \ldots, (x_n,y_n)$. That is, for a new $(x',y')$, how well does the model prediction $f(x')$ match with $y'$?

# %% [markdown]
# One sensible approach is to fit the model only using part of the data, say 70-80% of the data points -- these are called the _training_ data.  The remaining data points can be used to test the fitted model --  these are called the _test_ data. For a good model, we expect that the mean-squared error (or $R^2$ coefficient) on the test data should not be too much higher than on the training data.
#
# Let's look at an example.

# %%
import math
import numpy as np

training_data = np.load('Data/example_training_data.npy')
print(np.shape(training_data))
# Out:
# (100, 2)

# %% [markdown]
# The training data consists of 100 data points. The first column of the array contains the $x$ values and the second column the corresponding $y$ values. Let us plot these in a scatter plot.

# %%
import matplotlib.pyplot as plt

xtrain = training_data[:,0] #first column has the x-values
ytrain = training_data[:,1] #second column has the y-values
plt.scatter(xtrain, ytrain)
plt.title('Training data')
plt.show()
plt.rcParams['figure.figsize'] = [12, 7]
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 20

# %% [markdown]
# ### Fitting a linear model
#
# Let us fit a linear model $f(x) = \beta_0 + \beta_1 x$ to these data.

# %%
# form the X-transpose matrix and then the X matrix
all_ones = np.ones(np.size(xtrain))
XT = np.vstack((all_ones, xtrain))
X = np.transpose(XT)

# Compute the least-squares coefficients for the linear model
beta_lin = np.linalg.inv(XT.dot(X)).dot(XT.dot(ytrain))

# Compute the fit of the model
fit_lin = X.dot(beta_lin)

plt.scatter(xtrain, ytrain)
# plot the straight line fit
plt.plot(xtrain, fit_lin, color = 'red')
plt.title('Fit to the training data')
plt.show()

# %% [markdown]
# We now compute the _training_ error, which is the MSE of the fit with respect to the training data.

# %%
MSE_lin_train = np.linalg.norm(ytrain - fit_lin)**2/(np.size(ytrain))
print('MSE of linear model on training data: ', np.round(MSE_lin_train,4))
# Out:
# MSE of linear model on training data:  3.5642

# %% [markdown]
# Let us now load the test data. The test data consists of 40 new $(x,y)$ pairs

# %%
test_data = np.load('Data/example_test_data.npy')
print(np.shape(test_data))

xtest = test_data[:,0] #first column contains the x-values of the test data
ytest = test_data[:,1]
plt.scatter(xtest, ytest)
plt.title('Test data')
plt.show()
# Out:
# (40, 2)

# %% [markdown]
# We now compute the fit of the linear model for the test data, plot it, and compute the SSE for the test data.  We emphasize that the model has been fit using only the training data, so the test set provides a way to validate the model.

# %%
#Compute the fit of the linear model: \beta_0 + \beta_1 x

test_ones = np.ones(np.shape(xtest))
fit_lin_test = beta_lin[0]*test_ones + beta_lin[1]*xtest

#Plot the fit together with scatter plot of test data
plt.scatter(xtest, ytest)
plt.plot(xtest, fit_lin_test, 'r')
plt.title('Linear fit to the test data')
plt.show()

#Compute MSE on the test data
MSE_lin_test = np.linalg.norm(ytest - fit_lin_test)**2/(np.size(ytest))
print('MSE of linear model on test data: ', np.round(MSE_lin_test, decimals =4))
# Out:
# MSE of linear model on test data:  3.3996

# %% [markdown]
# Observe that the MSE of the linear model on the test data is similar to its MSE on training data. In fact, the test MSE is a bit lower. This is good.

# %% [markdown]
# ### Fitting a quadratic model
#
# We now fit a quadratic model $f(x) = \beta_0 + \beta_1 x + \beta_2 x^2$ to the training data, and then test the fit on the test data

# %%
# form the X-transpose matrix and then the X matrix
all_ones = np.ones(np.size(xtrain))
XT = np.vstack((all_ones, xtrain, xtrain**2))
X = np.transpose(XT)

# Compute the least-squares coefficients for the quadratic model
beta_quad = np.linalg.inv(XT.dot(X)).dot(XT.dot(ytrain))

# Compute the fit of the model
fit_quad = X.dot(beta_quad)

#scatterplot of data
plt.scatter(xtrain, ytrain)

# plot the straight line (red) and the quadratic fit (green)
plt.plot(xtrain, fit_lin, 'r')
plt.plot(xtrain, fit_quad, 'g')
plt.title('Linear and quadratic fits to the training data')
plt.show()

# %% [markdown]
# We now compute the training error of the quadratic fit.

# %%
MSE_quad_train = np.linalg.norm(ytrain - fit_quad)**2/(np.size(ytrain))
print('MSE of quadratic model on training data: ', np.round(MSE_quad_train, decimals =4))
print('MSE of linear model on training data: ', np.round(MSE_lin_train, decimals=4))
# Out:
# MSE of quadratic model on training data:  3.4452
# MSE of linear model on training data:  3.5642

# %% [markdown]
# As expected, the quadratic model gives a lower MSE on the training data. But let us now use the test data to examine whether it is worth fitting a quadratic model.

# %%
#Compute the fit of the quadratic model on test data

test_ones = np.ones(np.shape(xtest))
fit_quad_test = beta_quad[0]*test_ones + beta_quad[1]*xtest + beta_quad[2]*(xtest**2)

#Plot the fits together with scatter plot of test data
plt.scatter(xtest, ytest)
plt.plot(xtest, fit_quad_test, 'g', label = 'quadratic')
plt.plot(xtest, fit_lin_test, 'r', label = 'linear')
plt.title('Linear vs quadratic fits to the test data')
plt.show()

#Compute MSE on the test data
MSE_quad_test = np.linalg.norm(ytest - fit_quad_test)**2/(np.size(ytest))
print('MSE of quadratic model on test data: ', np.round(MSE_quad_test, decimals =4))
print('MSE of linear model on test data: ', np.round(MSE_lin_test, decimals =4))
# Out:
# MSE of quadratic model on test data:  7.7583
# MSE of linear model on test data:  3.3996

# %% [markdown]
# We see that the quadratic model is a much worse fit on the test data, having more than twice the MSE of the linear model. Therefore, there is no justification for choosing the quadratic model, and we stick with the simpler linear model.
#
# In this case, the quadratic model _overfits_ the training data, leading to poor performance for the test data.
# Unless the test MSE of the quadratic model is significantly lower than that of the linear model, we might prefer to stick with the linear model.

# %% [markdown]
# # Linear vs quadratic fit for CO$_2$ data
#
# We have split the CO$_2$ data set into a training set and a test set. Let us load and plot these.

# %%
training_CO2 = np.load('Data/CO2_training_data.npy')
xtrain = training_CO2[:,0]
ytrain = training_CO2[:,1]

test_CO2 = np.load('Data/CO2_test_data.npy')
xtest = test_CO2[:,0]
ytest = test_CO2[:,1]

plt.rcParams['figure.figsize'] = [12, 5]
plt.subplot(121)
plt.scatter(xtrain, ytrain, s=10)
plt.title('CO$_2$ training data')
plt.subplot(122)
plt.scatter(xtest, ytest, s=10)
plt.title('CO$_2$ test data')
plt.tight_layout()

# %%
# Find quadratic fit for training data
all_ones = np.ones(np.size(xtrain))
XT = np.vstack((all_ones, xtrain, xtrain**2))
X = np.transpose(XT)

beta_quad = np.linalg.inv(XT.dot(X)).dot(XT.dot(ytrain))
fit_quad = X.dot(beta_quad)


#scatterplot of data
plt.scatter(xtrain, ytrain, s=5)

# plot the straight line (red) and the quadratic fit (green)
plt.plot(xtrain, fit_quad, 'g')
plt.title('Quadratic fits to the training data')
plt.show()

# %%
# Plot residuals
resid_quad = ytrain - fit_quad

plt.rcParams['figure.figsize'] = [12, 5]
plt.subplot(211)
plt.scatter(xtrain, resid_quad, s=20)
plt.title('Residuals of the quadratic model')
plt.subplot(212)
plt.scatter(xtrain[301:350], resid_quad[301:350], s=20) 
plt.tight_layout()

# %%
# Plot the periodogram
N = np.size(xtrain)
T = xtrain[301] - xtrain[300] 


# Compute the squared magnitudes of the DFT coefficients -- this is known as the "periodogram"
pgram = np.abs(np.fft.fft(resid_quad, N)/N)**2 # We normalize by N, but this is optional
indices = np.linspace(0, (N-1), num = N)
freqs_in_hz = indices/(N*T)
freqs_in_rads = freqs_in_hz*2*math.pi

plt.subplot(211)
plt.plot(indices, pgram)
plt.xlabel('k')
plt.ylabel('Squared mag. $|G_k|^2/N^2$')
plt.tight_layout()

# Code to identify the indices for which the periodogram value exceeds 50% of the maximum
top_inds = indices[(pgram > 0.5*np.max(pgram))] 
print('Top indices:', top_inds)
# Out:
# Top indices: [ 43. 464.]

# %%
w = 2*math.pi*top_inds[0]/(N*T)  # Freq. in rad/s corresponding to k* is w = 2.pi.k*/(NT)

# Now form the X matrix with columns sin(wx) and cos(wx) for x in dates. First define its transpose
XT = np.vstack((np.sin(w*xtrain), np.cos(w*xtrain)))
X = np.transpose(XT)

beta_sc = np.linalg.inv(XT.dot(X)).dot(XT).dot(resid_quad) # Calculating the least-squares coefficients
fit_sc = X.dot(beta_sc)
fit_combined = fit_quad + fit_sc

# Plot combined fit on training data
plt.rcParams['figure.figsize'] = [14, 8]
plt.scatter(xtrain, ytrain, s=10)
plt.plot(xtrain, fit_combined, 'r')
plt.xlabel('Month')
plt.ylabel('CO$_2$ concentration (ppm)')
plt.title('Average monthly concentration of CO$_2$ for Training Data')
plt.show()

# Calculate and print SSE, MSE and R^2 for training data
resid_final = resid_quad - fit_sc
SSE_0 = np.linalg.norm(ytrain - np.mean(ytrain))**2
SSE_final = np.linalg.norm(resid_final)**2
MSE_final = SSE_final/np.size(ytrain)
print('For the Training Data: ')
print('Sum of squared errors SSE for linear + sinusoid model is:', np.round(SSE_final, 3)) 
print('Mean squared error MSE for linear + sinusoid model is:',  np.round(MSE_final,3))
print('R^2 for the linear + sinusoid model = ', np.round_(1- SSE_final/SSE_0, 3))
# Out:
# For the Training Data:
# Sum of squared errors SSE for linear + sinusoid model is: 1256.037
# Mean squared error MSE for linear + sinusoid model is: 2.477
# R^2 for the linear + sinusoid model =  0.991

# %%
#Compute the fit of the combined model on test data
XT2 = np.vstack((np.sin(w*xtest), np.cos(w*xtest)))
X2 = np.transpose(XT2)

test_ones = np.ones(np.shape(xtest))
fit_quad_test = beta_quad[0]*test_ones + beta_quad[1]*xtest + beta_quad[2]*(xtest**2)
fit_sc_test = X2.dot(beta_sc)
fit_combined_test = fit_quad_test + fit_sc_test

#Plot the fits together with scatter plot of test data
plt.scatter(xtest, ytest, s=5)
plt.plot(xtest, fit_quad_test, 'g', label= 'Quadratic Fit')
plt.plot(xtest, fit_combined_test, 'r', label = 'Combined Fit')
plt.xlabel('Month')
plt.ylabel('CO$_2$ concentration (ppm)')
plt.title('Average monthly concentration of CO$_2$ for Test Data')
plt.legend(fontsize = 'large')
plt.show()

# Calculate and print SSE, MSE and R^2 for test data
resid_final_test = ytest - fit_quad_test - fit_sc_test
SSE_0_test = np.linalg.norm(ytest - np.mean(ytest))**2
SSE_final_test = np.linalg.norm(resid_final_test)**2
MSE_final_test = SSE_final/np.size(ytest)
print('For the Test Data (Combined Fit): ')
print('Sum of squared errors SSE for quadratic + sinusoid model is:', np.round(SSE_final_test, 3)) 
print('Mean squared error MSE for quadratic + sinusoid model is:',  np.round(MSE_final_test,3))
print('R^2 for the quadratic + sinusoid model = ', np.round_(1- SSE_final_test/SSE_0_test, 3))

SSE_quad_test = np.linalg.norm(ytest - fit_quad_test)**2
MSE_quad_test = SSE_quad_test/np.size(ytest)
print('\nFor the Test Data (Quadratic Fit): ')
print('Sum of squared errors SSE for quadratic model is:', np.round(SSE_quad_test, 3)) 
print('Mean squared error MSE for quadratic model is:',  np.round(MSE_quad_test,3))
print('R^2 for the quadratic model = ', np.round_(1- SSE_quad_test/SSE_0_test, 3))
# Out:
# For the Test Data (Combined Fit):
# Sum of squared errors SSE for quadratic + sinusoid model is: 1959.079
# Mean squared error MSE for quadratic + sinusoid model is: 5.683
# R^2 for the quadratic + sinusoid model =  0.937
#
# For the Test Data (Quadratic Fit):
# Sum of squared errors SSE for quadratic model is: 1238.445
# Mean squared error MSE for quadratic model is: 5.604
# R^2 for the quadratic model =  0.96

# %% [markdown]
# The MSE increased for both the quadratic and combined fit model on the test data, but the quadratic model being a slightly lower.
# The combined fit model has a lower R^2 coefficient but still remains high and similar to that of the training data, which suggests that this model is still a good prediction of future data.
# However, the R^2 coefficient of the quadratic model is higher than that of the combined fit, which could suggest that we are overfitting the data when it comes to our sinusoidal model for the detrended residuals.

# %% [markdown]
# ## Optional exercise (will not be marked):
#
# - Fit a model to training data using the same steps as in notebooks 1 and 2. That is, fit a quadratic model for the trend and a sinusoidal model for the detrended residuals.
# - Validate the model on the test data, by comparing the MSE and $R^2$ values for the training data with those obtained for the test data.

# %% [markdown]
# # Summary
#
# -  We used a simple approach for model selection: divide your available data into "training data" and "test data" (say, in 70:30 proportion). Fit your model to the training data, and check its performance on the test data.
# -  For a good model, the performance on the training and test data must be similar.
#
# - We only considered one partition of the data into training and test sets. Clearly, there are many ways we can split the data into training and test sets. Averaging the test MSE over all these splits would give a more robust estimate of the test error. This procedure is called _cross-validation_. (See references below.)
#
# - In some situations we may not have enough data points available to set aside a portion of them as test data, i.e., we may want to make use of all the available data to fit a decent model. There is a variety of more sophisticated methods and metrics that can be used for model selection in such cases. Subset selection, and Forward/Backward-stepwise selection are some examples.  If you are interested in learning more, have a look at the references below.

# %% [markdown]
# # References
#
# 1. _Introduction to Statistical Learning_, by G. James, D. Witten, T. Hastie, R. Tibshirani. A free downloadable copy of the book is available [here](http://faculty.marshall.usc.edu/gareth-james/ISL/).  Chapters 5,6 discuss model selection. (Also read Chapter 2.2 for background.)
# 1. _Elements of Statistical Learning_, by T. Hastie, R. Tibshirani, J. Friedman. Free downloadable copy available [here](https://web.stanford.edu/~hastie/ElemStatLearn/). This book covers similar topics as the above but with more mathematical detail and rigour. Chapter 7 discusses model selection.
